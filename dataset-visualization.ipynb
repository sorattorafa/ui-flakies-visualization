# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.pyplot import pie, axis, show

# %%
dataset = pd.read_csv('data/dataset.csv', 
    usecols=['Root Cause Category', 'Manifestation Category', 'Fix Category', 'Testing Environment/Runner'], sep=',')
columns = dataset.columns.to_list()
dataset = dataset.applymap(lambda s:s.lower() if type(s) == str else s)

def make_quantity_plots(dataset, column, title):

    count = dataset[column].value_counts().values
    categories = dataset[column].value_counts().index


    plt.figure(figsize = (30, 8))
    plt.subplot(1, 2, 1)

    dataset[column].value_counts().plot(kind='barh', title=column)
    plt.ylabel(column)
    plt.xlabel("Quantity")
    plt.title(title)
    plt.subplot(1, 2, 2)
    plt.pie(count,
            autopct='%1.1f%%',
            labels = list(categories),  
            colors = ["#20257c", "#424ad1", "#6a8ee8", "#66bbe2", "#66dee2", "#6ce2cb", "#6ad187", "#3b7f5b"],
            labeldistance = 1.8,
            wedgeprops = {"ec": "k"}, 
            textprops = {"fontsize": 11}, 
            )
    plt.axis("equal")
    plt.title(title)
    plt.legend()

# %%
make_quantity_plots(dataset, 'Root Cause Category', 'Root Cause Category')

# %%
make_quantity_plots(dataset, 'Manifestation Category', 'Manifestation Category')
# Out:
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
make_quantity_plots(dataset, 'Fix Category', 'Fix flaky methods')
# Out:
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/rafael/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def make_quantity_plots_enviroments(dataset, column, title):

    count = dataset[column].value_counts().values
    categories = dataset[column].value_counts().index


    plt.figure(figsize = (30, 8))
    plt.subplot(1, 2, 1)

    dataset[column].value_counts().plot(kind='barh', title=column, color = '#20257c', edgecolor = 'black'),
    plt.ylabel(column)
    plt.xlabel("Quantity")
    plt.title(title)
    plt.subplot(1, 2, 2)
    plt.pie(count, 
            labels = list(categories),  
            colors = ["#20257c", "#424ad1", "#6a8ee8", "#66bbe2", "#66dee2", "#6ce2cb", "#6ad187", "#3b7f5b"],
            labeldistance = 1.8,
            wedgeprops = {"ec": "k"}, 
            textprops = {"fontsize": 11}, 
            )
    plt.axis("equal")
    plt.title(title)
    plt.legend()

# %%
make_quantity_plots_enviroments(dataset, 'Testing Environment/Runner', 'Testing Environment/Runner')
